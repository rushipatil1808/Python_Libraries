# %% [markdown]
# Types Of Data--> Fundamental of Matplotlib

# %%
#Data Type 
#numerical data
#categorical data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
