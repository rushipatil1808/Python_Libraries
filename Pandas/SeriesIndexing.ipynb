# %%
import pandas as pd
import numpy as np

marks = [67,78,88,100,89]
subject =['maths','English','marathi','Dsa','SC']

marks = pd.Series(marks,index=subject,name = 'Rushi che marks')
marks
# Out:
# maths       67
# English     78
# marathi     88
# Dsa        100
# SC          89
# Name: Rushi che marks, dtype: int64

# %%
import pandas as pd

#sub = pd.read_csv(r'E:\PythonLibraries\Pandas\subs.csv')
sub = pd.read_csv(r'E:\PythonLibraries\Pandas\subs.csv').squeeze("columns")
print(sub)
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
import pandas as pd

vk = pd.read_csv(r'E:\PythonLibraries\Pandas\kohli_ipl.csv',index_col='match_no').squeeze("columns")

print(vk)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
import pandas as pd

movies = pd.read_csv(
    r'E:\PythonLibraries\Pandas\bollywood.csv',
    index_col='movie'
).squeeze("columns")

print(movies)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
#Series Indexing 

import pandas as pd

x = pd.Series([12,33,44,67,55,66,34,64])
x[1]
# Out:
# np.int64(33)

# %%
movies[14]
# Out:
# C:\Users\rushi\AppData\Local\Temp\ipykernel_17972\1202097761.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[14]
# 'Sushant Singh Rajput'

# %%
#slicing
vk[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
#fancy Indexing 
vk[[1,2,3,4,5]]
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %% [markdown]
# Editing Series

# %%
#using Indexing 

marks[1] = 100
marks
# Out:
# C:\Users\rushi\AppData\Local\Temp\ipykernel_17972\1124964411.py:3: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks[1] = 100
# maths       67
# English    100
# marathi     88
# Dsa        100
# SC          89
# Name: Rushi che marks, dtype: int64

# %%
marks['sst'] = 90
marks
# Out:
# maths       67
# English    100
# marathi     88
# Dsa        100
# SC          89
# sst         90
# Name: Rushi che marks, dtype: int64

# %%
#slicing   (write opption in pandas)
vk[2:4] == [100,100]
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %% [markdown]
# Series With python Functionalities

# %%
#len/type/dir/sorted/max/min
print(len(vk))
print(type(sub))
print(dir(sub))
print(sorted(sub))
print(min(sub))
print(max(sub))
# Out:
# 215
# <class 'pandas.core.series.Series'>
# ...

# %%
#type conversion
list(marks)
# Out:
# [67, 100, 88, 100, 89, 90]

# %%
dict(marks)
# Out:
# {'maths': np.int64(67),
#  'English': np.int64(100),
#  'marathi': np.int64(88),
#  'Dsa': np.int64(100),
#  'SC': np.int64(89),
#  'sst': np.int64(90)}

# %%
#membership Operator 
'2 State (2014 film)' in movies
# Out:
# False

# %%
#looping 
for i in movies.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
#arithmetic Operators (Broadcasting )
100 + marks
# Out:
# maths      167
# English    200
# marathi    188
# Dsa        200
# SC         189
# sst        190
# Name: Rushi che marks, dtype: int64

# %%
#Realatinal Oprator 
vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# Boolean Indexing on Series

# %%
#find no of 50 and 100 scored by kohli

vk[vk >= 50]
# Out:
# match_no
# 15      50
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 182     50
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %%
#find num of ducks
vk[vk == 0]
# Out:
# match_no
# 8      0
# 87     0
# 91     0
# 93     0
# 130    0
# 135    0
# 206    0
# 207    0
# 211    0
# Name: runs, dtype: int64

# %%
#count number of day when i had more than 200 subs a day 
sub[sub > 200].size
# Out:
# 59

# %%
#find actors who have done more than 

num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# Plotting Graphs

# %%
sub.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
