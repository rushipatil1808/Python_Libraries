# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd

student = pd.read_csv(r"C:\Users\rushi\Downloads\students.csv")
dec = pd.read_csv(r"C:\Users\rushi\Downloads\reg-month2.csv")
nov = pd.read_csv(r"C:\Users\rushi\Downloads\reg-month1.csv")
matches = pd.read_csv(r"C:\Users\rushi\Downloads\matches.csv")
ball = pd.read_csv(r"C:\Users\rushi\Downloads\deliveries.csv")
courses = pd.read_csv(r"C:\Users\rushi\Downloads\courses.csv")

# %%
#pd.concat
#df.concat
#ignore_index
#df.append
#mullitindex -->fetch using iloc
#concat dataframe horizontally

# %%
reg = pd.concat([nov,dec],ignore_index=True)
reg
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
multi = pd.concat([nov, dec], keys=['Nov', 'Dec'])
multi.loc[('Dec',4)]
# Out:
# student_id    14
# course_id      9
# Name: (Dec, 4), dtype: int64

# %%
pd.concat([nov, dec], axis=1, keys=['Nov', 'Dec']).sample(6)
# Out:
#           Nov                  Dec
#    student_id course_id student_id course_id
# 25        NaN       NaN         42         9
# 4        16.0       9.0         14         9
# 14       13.0       3.0          1        10
# 16       21.0       1.0          2         5
# 20       23.0       6.0         23         9
# 12        7.0      10.0         12         7

# %% [markdown]
# Merge
# Inner Join,Left Join, right Join ,outer join

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#inner join
student.merge(reg,how='inner',on='student_id').sample(6)
# Out:
#     student_id             name  partner  course_id
# 6            3   Parveen Bhalla        3          5
# 8            7     Tarun Thaker        9         10
# 34          18  Fardeen Mahabir       13          8
# 1            1    Kailash Harjo       23          6
# 15          12       Radha Dutt       19         10
# 0            1    Kailash Harjo       23          1

# %%
#left Join
courses.merge(reg,how='left',on='course_id').sample(6)
# Out:
#     course_id       course_name  price  student_id
# 16          4  machine learning   9999        23.0
# 28          6          power bi   1899         1.0
# 41          8            pandas   1099        50.0
# 48         10           pyspark   2499        25.0
# 21          5           tableau   2499        16.0
# 11          3     data analysis   4999        22.0

# %%
#right join

# right join data
import numpy as np
import pandas as pd

temp_df = pd.DataFrame({
    'student_id':[26,27,28],
    'name':['Nitish','Ankit','Rahul'],
    'partner':[28,26,17]
})

student = pd.concat([student, temp_df], ignore_index=True)

# %%
student.tail()
# Out:
#     student_id             name  partner
# 23          24     Radhika Suri       17
# 24          25  Shashank D’Alia        2
# 25          26           Nitish       28
# 26          27            Ankit       26
# 27          28            Rahul       17

# %%
student.merge(reg,how='right',on='student_id').sample(6)
# Out:
#     student_id              name  partner  course_id
# 0           23    Chhavi Lachman     18.0          1
# 44          22        Yash Sethi     21.0          6
# 9           15         Preet Sha     16.0          1
# 29          14  Pranab Natarajan     22.0          9
# 22          19      Qabeel Raman     12.0          2
# 10          19      Qabeel Raman     12.0          4

# %%
#outer join 
student.merge(reg,how='outer',on='student_id').tail(10)
# Out:
#     student_id             name  partner  course_id
# 53          23   Chhavi Lachman     18.0        5.0
# 54          24     Radhika Suri     17.0        4.0
# 55          25  Shashank D’Alia      2.0        1.0
# 56          25  Shashank D’Alia      2.0       10.0
# 57          26           Nitish     28.0        NaN
# 58          27            Ankit     26.0        NaN
# 59          28            Rahul     17.0        NaN
# 60          38              NaN      NaN        1.0
# 61          42              NaN      NaN        9.0
# 62          50              NaN      NaN        8.0

# %% [markdown]
# Quetion AnS
